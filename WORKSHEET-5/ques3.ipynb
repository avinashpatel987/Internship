# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import urllib
import os

# %%
s=Service("C:\chromedriver_win32\chromedriver.exe")
driver=webdriver.Chrome(service=s)
driver.get('https://www.guru99.com/')

# %%
driver.find_element(By.XPATH,'//*[@id="gsc-i-id1"]').send_keys("selenium exception handling")

# %%
btn1=driver.find_element(By.XPATH,"//*[@id='___gcse_0']/div/div/form/table/tbody/tr/td[2]/button")
btn1.click()

# %%
btn2=driver.find_element(By.XPATH,"//*[@id='___gcse_0']/div/div/div/div[5]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a")
btn2.click()

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
all_=driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td")
all_[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="cef78f4af1d91842fd17c017638d6657", element="006cbd3b-9f39-4c29-80ce-d4d2054d0d42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cef78f4af1d91842fd17c017638d6657", element="0b683ae0-0fdd-48f2-b019-33431caf78e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cef78f4af1d91842fd17c017638d6657", element="ed16fc56-29cc-47ba-bbbb-7d66249269c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="cef78f4af1d91842fd17c017638d6657", element="3c8d705b-fd90-4a02-afbb-3f44d4644fd4")>]

# %%
a=[]
for i in all_:
    temp=i.text
    a.append(temp)
a[0:4]
# Out:
# ['ElementNotVisibleException',
#  'This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'ElementNotSelectableException',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.']

# %%
excep=[]
desc=[]
excep=a[::2]
desc=a[1::2]

# %%
dataset=pd.DataFrame()
dataset['Exception']=excep
dataset['Description']=desc
dataset
# Out:
#                               Exception  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...
