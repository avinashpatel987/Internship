# %% [markdown]
# # ii) Top 10 women’s ODI players along with the records of their team and rating.

# %% [markdown]
# # Importing Library

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import string
import re

# %% [markdown]
# # Getting URL of the Website

# %%
url='https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting'
cont=requests.get(url)
htmlContent=cont.content

# %% [markdown]
# # Creating The soup

# %%
soup=BeautifulSoup(htmlContent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %% [markdown]
# # Names

# %%
head=soup.find_all('td',class_="table-body__cell rankings-table__name name")
head
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/558">Mithali Raj</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1817">Beth Mooney</a>
#  </td>,
# ...

# %%
D=[]
for i in head:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    D.append(i)
D
# Out:
# ['Alyssa Healy',
#  'Mithali Raj',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Heather Knight',
#  'Laura Wolvaardt',
#  'Rachael Haynes',
#  'Stafanie Taylor',
#  'Ellyse Perry',
#  'Mignon du Preez',
#  'Natalie Sciver',
#  'Chamari Athapaththu',
#  'Sophie Devine',
#  'Harmanpreet Kaur',
#  'Deepti Sharma',
#  'Marizanne Kapp',
#  'Amy Jones',
#  'Poonam Raut',
#  'Suzie Bates',
#  'Deandra Dottin',
#  'Nahida Khan',
#  'Dane van Niekerk',
#  'Ashleigh Gardner',
#  'Bismah Maroof',
#  'Danielle Wyatt',
#  'Javeria Khan',
#  'Brooke Halliday',
#  'Hayley Matthews',
#  'Fargana Hoque',
#  'Gaby Lewis',
#  'Maddie Green',
#  'Rumana Ahmed',
#  'Katherine Brunt',
#  'Laura Delany',
#  'Lauren Winfield',
#  'Umaima Sohail',
#  'Nida Dar',
#  'Chloe-Lesleigh Tryon',
#  'Katey Martin',
#  'Aliya Riaz',
#  'Katie Perkins',
#  'Amelia Kerr',
#  'Jess Jonassen',
#  'Sune Luus',
#  'Tahlia McGrath',
#  'Jhulan Goswami',
# ...

# %%
head2=soup.find_all('div',class_="rankings-block__banner--name-large")
head2
# Out:
# [<div class="rankings-block__banner--name-large">Lizelle Lee</div>]

# %%
D2=[]
for i in head2:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    D2.append(i)
D2
# Out:
# ['Lizelle Lee']

# %%
wpn=[]
wpn=D2+D
wpn
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Mithali Raj',
#  'Tammy Beaumont',
#  'Amy Satterthwaite',
#  'Smriti Mandhana',
#  'Meg Lanning',
#  'Beth Mooney',
#  'Heather Knight',
#  'Laura Wolvaardt',
#  'Rachael Haynes',
#  'Stafanie Taylor',
#  'Ellyse Perry',
#  'Mignon du Preez',
#  'Natalie Sciver',
#  'Chamari Athapaththu',
#  'Sophie Devine',
#  'Harmanpreet Kaur',
#  'Deepti Sharma',
#  'Marizanne Kapp',
#  'Amy Jones',
#  'Poonam Raut',
#  'Suzie Bates',
#  'Deandra Dottin',
#  'Nahida Khan',
#  'Dane van Niekerk',
#  'Ashleigh Gardner',
#  'Bismah Maroof',
#  'Danielle Wyatt',
#  'Javeria Khan',
#  'Brooke Halliday',
#  'Hayley Matthews',
#  'Fargana Hoque',
#  'Gaby Lewis',
#  'Maddie Green',
#  'Rumana Ahmed',
#  'Katherine Brunt',
#  'Laura Delany',
#  'Lauren Winfield',
#  'Umaima Sohail',
#  'Nida Dar',
#  'Chloe-Lesleigh Tryon',
#  'Katey Martin',
#  'Aliya Riaz',
#  'Katie Perkins',
#  'Amelia Kerr',
#  'Jess Jonassen',
#  'Sune Luus',
#  'Tahlia McGrath',
# ...

# %%
wpnact=wpn[:10]

# %%
cont=[]
cont=D[0:10]

# %% [markdown]
# # Country

# %%
bn=soup.find_all('span',class_='table-body__logo-text')
bn
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
# ...

# %%
bn2=soup.find_all('div',class_='rankings-block__banner--nationality')
bn2
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 SA"></div>
#  <span class="rankings-block__banner--nation"></span>SA
#  </div>]

# %%
cn2=[]
for i in bn2:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    cn2.append(i)
cn2
# Out:
# ['SA']

# %%
cn=[]
for i in bn:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    cn.append(i)
cn
# Out:
# ['AUS',
#  'IND',
#  'ENG',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'ENG',
#  'SA',
#  'AUS',
#  'WI',
#  'AUS',
#  'SA',
#  'ENG',
#  'SL',
#  'NZ',
#  'IND',
#  'IND',
#  'SA',
#  'ENG',
#  'IND',
#  'NZ',
#  'WI',
#  'PAK',
#  'SA',
#  'AUS',
#  'PAK',
#  'ENG',
#  'PAK',
#  'NZ',
#  'WI',
#  'BAN',
#  'IRE',
#  'NZ',
#  'BAN',
#  'ENG',
#  'IRE',
#  'ENG',
#  'PAK',
#  'PAK',
#  'SA',
#  'NZ',
#  'PAK',
#  'NZ',
#  'NZ',
#  'AUS',
#  'SA',
#  'AUS',
#  'IND',
#  'SA',
#  'SL',
#  'IND',
#  'WI',
#  'AUS',
#  'BAN',
#  'SL',
#  'WI',
#  'IND',
#  'IRE',
#  'SA',
#  'ZIM',
#  'ENG',
#  'WI',
#  'IND',
#  'NZ',
#  'IND',
#  'PAK',
#  'ZIM',
#  'IND',
#  'ENG',
#  'SL',
#  'WI',
#  'NZ',
#  'WI',
#  'NZ',
#  'PAK',
#  'IRE',
#  'BAN',
#  'IRE',
#  'ENG',
#  'NZ',
#  'AUS',
#  'IND',
#  'IND',
#  'SL',
#  'IND',
#  'NZ',
#  'BAN',
#  'WI',
#  'IRE',
#  'IRE',
#  'ENG',
#  'SA',
#  'IND',
#  'IND',
#  'SL',
#  'SA',
#  'NZ',
#  'SL']

# %%
cnr=[]
cnr=cn2+cn
cnr
# Out:
# ['SA',
#  'AUS',
#  'IND',
#  'ENG',
#  'NZ',
#  'IND',
#  'AUS',
#  'AUS',
#  'ENG',
#  'SA',
#  'AUS',
#  'WI',
#  'AUS',
#  'SA',
#  'ENG',
#  'SL',
#  'NZ',
#  'IND',
#  'IND',
#  'SA',
#  'ENG',
#  'IND',
#  'NZ',
#  'WI',
#  'PAK',
#  'SA',
#  'AUS',
#  'PAK',
#  'ENG',
#  'PAK',
#  'NZ',
#  'WI',
#  'BAN',
#  'IRE',
#  'NZ',
#  'BAN',
#  'ENG',
#  'IRE',
#  'ENG',
#  'PAK',
#  'PAK',
#  'SA',
#  'NZ',
#  'PAK',
#  'NZ',
#  'NZ',
#  'AUS',
#  'SA',
#  'AUS',
#  'IND',
#  'SA',
#  'SL',
#  'IND',
#  'WI',
#  'AUS',
#  'BAN',
#  'SL',
#  'WI',
#  'IND',
#  'IRE',
#  'SA',
#  'ZIM',
#  'ENG',
#  'WI',
#  'IND',
#  'NZ',
#  'IND',
#  'PAK',
#  'ZIM',
#  'IND',
#  'ENG',
#  'SL',
#  'WI',
#  'NZ',
#  'WI',
#  'NZ',
#  'PAK',
#  'IRE',
#  'BAN',
#  'IRE',
#  'ENG',
#  'NZ',
#  'AUS',
#  'IND',
#  'IND',
#  'SL',
#  'IND',
#  'NZ',
#  'BAN',
#  'WI',
#  'IRE',
#  'IRE',
#  'ENG',
#  'SA',
#  'IND',
#  'IND',
#  'SL',
#  'SA',
#  'NZ',
#  'SL']

# %%
cnact=cnr[:10]

# %% [markdown]
# # Rating

# %%
ratng=soup.find_all('td',class_='table-body__cell rating')
ratng
# Out:
# [<td class="table-body__cell rating">750</td>,
#  <td class="table-body__cell rating">738</td>,
#  <td class="table-body__cell rating">728</td>,
#  <td class="table-body__cell rating">717</td>,
#  <td class="table-body__cell rating">710</td>,
#  <td class="table-body__cell rating">699</td>,
#  <td class="table-body__cell rating">690</td>,
#  <td class="table-body__cell rating">674</td>,
#  <td class="table-body__cell rating">672</td>,
#  <td class="table-body__cell rating">668</td>,
#  <td class="table-body__cell rating">665</td>,
#  <td class="table-body__cell rating">649</td>,
#  <td class="table-body__cell rating">648</td>,
#  <td class="table-body__cell rating">642</td>,
#  <td class="table-body__cell rating">594</td>,
#  <td class="table-body__cell rating">563</td>,
#  <td class="table-body__cell rating">559</td>,
#  <td class="table-body__cell rating">543</td>,
#  <td class="table-body__cell rating">538</td>,
#  <td class="table-body__cell rating">537</td>,
# ...

# %%
rt=[]
for i in ratng:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    rt.append(i)
rt
# Out:
# ['750',
#  '738',
#  '728',
#  '717',
#  '710',
#  '699',
#  '690',
#  '674',
#  '672',
#  '668',
#  '665',
#  '649',
#  '648',
#  '642',
#  '594',
#  '563',
#  '559',
#  '543',
#  '538',
#  '537',
#  '537',
#  '530',
#  '521',
#  '506',
#  '489',
#  '477',
#  '470',
#  '466',
#  '453',
#  '449',
#  '437',
#  '429',
#  '426',
#  '424',
#  '422',
#  '409',
#  '408',
#  '403',
#  '403',
#  '397',
#  '386',
#  '377',
#  '375',
#  '373',
#  '358',
#  '358',
#  '350',
#  '349',
#  '346',
#  '345',
#  '342',
#  '330',
#  '321',
#  '317',
#  '315',
#  '315',
#  '311',
#  '309',
#  '303',
#  '291',
#  '290',
#  '290',
#  '288',
#  '284',
#  '271',
#  '270',
#  '268',
#  '267',
#  '266',
#  '266',
#  '261',
#  '261',
#  '258',
#  '256',
#  '253',
#  '252',
#  '248',
#  '244',
#  '242',
#  '241',
#  '240',
#  '237',
#  '227',
#  '226',
#  '226',
#  '225',
#  '221',
#  '221',
#  '221',
#  '218',
#  '214',
#  '213',
#  '212',
#  '212',
#  '211',
#  '211',
#  '208',
#  '206',
#  '205']

# %%
ratng2=soup.find_all('div',class_='rankings-block__banner--rating')

# %%
rt2=[]
for i in ratng2:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    rt2.append(i)
rt2
# Out:
# ['761']

# %%
rtn=[]
rtn=rt2+rt

# %%
rtact=rtn[:10]

# %% [markdown]
# # Database

# %%
dataset=pd.DataFrame()
dataset['Player Names']=wpnact
dataset['Country']=cnact
dataset['Rating']=rtact
dataset.head(10)
# Out:
#         Player Names Country Rating
# 0        Lizelle Lee      SA    761
# 1       Alyssa Healy     AUS    750
# 2        Mithali Raj     IND    738
# 3     Tammy Beaumont     ENG    728
# 4  Amy Satterthwaite      NZ    717
# 5    Smriti Mandhana     IND    710
# 6        Meg Lanning     AUS    699
# 7        Beth Mooney     AUS    690
# 8     Heather Knight     ENG    674
# 9    Laura Wolvaardt      SA    672
