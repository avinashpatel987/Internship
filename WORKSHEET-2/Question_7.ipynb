# %% [markdown]
# # Write a python program to scrape house details from mentioned url. It should include house title, location, area, emi and price
# https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44N DUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8 iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0"

# %% [markdown]
# # Importing Library

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import string
import re
import urllib.request

# %%
header= {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

# %%
url='https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44N%20DUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8%20iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0'
c=requests.get(url,headers=header)
htmlContent=c.content

# %%
print(htmlContent)
# Out:
# b'\n          <!DOCTYPE html><html lang="en"><head>\n          <meta property="fb:pages" content="794951570520699" />\n          <link rel="canonical" href="https://www.nobroker.in" />\n          \n          \n           \n          <link rel="dns-prefetch" href="//www.googletagmanager.com">\n          <link rel="dns-prefetch" href="//www.google-analytics.com">\n          <link rel="dns-prefetch" href="//assets.nobroker.in">\n          <link rel="dns-prefetch" href="//images.nobroker.in">\n          <link rel="shortcut icon" id="favicon" href="//assets.nobroker.in/static/img/favicon.png"/>\n          <link rel="apple-touch-icon" href="https://images.nobroker.in/static/img/fav64.png">\n          <meta charset="utf-8"/><meta charset="UTF-8"/>\n          <meta name="google-play-app" content="app-id=com.nobroker.app&referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb">\n    \t    <meta name="apple-itunes-app" content="app-id=1200507100, app-argument=nobrokerapp://">\n          <meta 
# ...

# %% [markdown]
# # Soup

# %%
soup=BeautifulSoup(htmlContent,'html.parser')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon">
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %% [markdown]
# # Heading

# %%
head=soup.find_all('span',itemprop='name')
head
# Out:
# [<span itemprop="name">Home </span>,
#  <span itemprop="name">Bangalore</span>,
#  <span itemprop="name">4 BHK In Independent House  For Sale  In Hebbagodi</span>,
#  <span itemprop="name">4 BHK In Independent House  For Sale  In Hebbagodi</span>,
#  <span itemprop="name">Independent House, Bangalore - Hosur Road, Near  National Public School</span>,
#  <span itemprop="name">4 BHK Flat  For Sale  In Sobha Silicon Oasis  In Hosa Road</span>,
#  <span itemprop="name">4 BHK Flat  For Sale  In Sobha Silicon Oasis  In Hosa Road</span>,
#  <span itemprop="name">Sobha Silicon Oasis Naganathapura, Rayasandra Bengaluru, Karnataka 560100 India</span>,
#  <span itemprop="name">4 BHK For Sale  In Daadys Garden In Electronic City</span>,
#  <span itemprop="name">4 BHK For Sale  In Daadys Garden In Electronic City</span>,
#  <span itemprop="name">Kammasandra Rd, Kammasandra, Electronic City, Bengaluru, Karnataka 560100, India</span>,
# ...

# %%
dele=soup.find_all('div',class_='nb__hVYWo')
dele
# Out:
# []

# %%
listBannerCard

# %%
h=[]
for i in head:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    h.append(i)
h
# Out:
# ['Home',
#  'Bangalore',
#  '4 BHK In Independent House  For Sale  In Hebbagodi',
#  '4 BHK In Independent House  For Sale  In Hebbagodi',
#  'Independent House, Bangalore - Hosur Road, Near  National Public School',
#  '4 BHK Flat  For Sale  In Sobha Silicon Oasis  In Hosa Road',
#  '4 BHK Flat  For Sale  In Sobha Silicon Oasis  In Hosa Road',
#  'Sobha Silicon Oasis Naganathapura, Rayasandra Bengaluru, Karnataka 560100 India',
#  '4 BHK For Sale  In Daadys Garden In Electronic City',
#  '4 BHK For Sale  In Daadys Garden In Electronic City',
#  'Kammasandra Rd, Kammasandra, Electronic City, Bengaluru, Karnataka 560100, India',
#  '4 BHK Flat  For Sale  In , Electronic City',
#  '4 BHK Flat  For Sale  In , Electronic City',
#  'Standalone Building, 16th Cross Road Neeladri Nagar, near by brand factory',
#  '4 BHK Flat  For Sale  In Hosa Road, Parappana Agrahara',
#  '4 BHK Flat  For Sale  In Hosa Road, Parappana Agrahara',
#  'Standalone Building, 11th cross.anjanadri lay out',
# ...

# %%
home=[]
home=h[2:12]

# %%
head2=soup.find_all('div',class_='nb__2CMjv')
head2
# Out:
# [<div class="nb__2CMjv">Independent House, Bangalore - Hosur Road, Near  National Public School</div>,
#  <div class="nb__2CMjv">Sobha Silicon Oasis Naganathapura, Rayasandra Bengaluru, Karnataka 560100 India</div>,
#  <div class="nb__2CMjv"><a class="nb__17tcx" href="/daadys-garden-electronic-city_bangalore-prjt-5ba009ad714b568105761868" target="_blank">Daadys Garden</a>  <!-- -->Kammasandra Rd, Kammasandra, Electronic City, Bengaluru, Karnataka 560100, India</div>,
#  <div class="nb__2CMjv">Standalone Building, 16th Cross Road Neeladri Nagar, near by brand factory</div>,
#  <div class="nb__2CMjv">Standalone Building, 11th cross.anjanadri lay out</div>,
#  <div class="nb__2CMjv">Independent House, surya nagar face 1</div>,
#  <div class="nb__2CMjv">Independent House, Hosur Rd,Near Infosys Limited</div>,
# ...

# %%
des=[]
for i in head2:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    des.append(i)
des
# Out:
# ['Independent House, Bangalore - Hosur Road, Near  National Public School',
#  'Sobha Silicon Oasis Naganathapura, Rayasandra Bengaluru, Karnataka 560100 India',
#  'Daadys Garden\xa0 Kammasandra Rd, Kammasandra, Electronic City, Bengaluru, Karnataka 560100, India',
#  'Standalone Building, 16th Cross Road Neeladri Nagar, near by brand factory',
#  'Standalone Building, 11th cross.anjanadri lay out',
#  'Independent House, surya nagar face 1',
#  'Independent House, Hosur Rd,Near Infosys Limited',
#  'Gopalan Gardenia\xa0 Gopalan gardenia, Veerasandra Main Rd, Veer Sandra, Electronic City, Bengaluru, Karnataka 560100, India',
#  '6th Cross',
#  'Standalone Building, Shikaripalya near Shams School']

# %% [markdown]
# # Area

# %%
head3=soup.find_all('div',class_='nb__3oNyC')
head3
# Out:
# [<div class="nb__3oNyC">1,800 sqft</div>,
#  <div class="nb__3oNyC">1,879 sqft</div>,
#  <div class="nb__3oNyC">2,600 sqft</div>,
#  <div class="nb__3oNyC">2,000 sqft</div>,
#  <div class="nb__3oNyC">3,000 sqft</div>,
#  <div class="nb__3oNyC">3,000 sqft</div>,
#  <div class="nb__3oNyC">1,200 sqft</div>,
#  <div class="nb__3oNyC">2,650 sqft</div>,
#  <div class="nb__3oNyC">3,100 sqft</div>,
#  <div class="nb__3oNyC">1,400 sqft</div>]

# %%
area=[]
for i in head3:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    area.append(i)
area
# Out:
# ['1,800 sqft',
#  '1,879 sqft',
#  '2,600 sqft',
#  '2,000 sqft',
#  '3,000 sqft',
#  '3,000 sqft',
#  '1,200 sqft',
#  '2,650 sqft',
#  '3,100 sqft',
#  '1,400 sqft']

# %% [markdown]
# # EMI

# %%
head4=soup.find_all('div',id='roomType')
head4
# Out:
# [<div class="font-semi-bold heading-6" id="roomType"><span>₹</span>77,374/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>9,170/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>85,971/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>39,546/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>71,643/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>1.43 Lacs/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>42,985/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>68,777/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>85,971/Month</div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>20,060/Month</div>]

# %%
emi=[]
for i in head4:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    emi.append(i)
emi
# Out:
# ['₹77,374/Month',
#  '₹9,170/Month',
#  '₹85,971/Month',
#  '₹39,546/Month',
#  '₹71,643/Month',
#  '₹1.43 Lacs/Month',
#  '₹42,985/Month',
#  '₹68,777/Month',
#  '₹85,971/Month',
#  '₹20,060/Month']

# %% [markdown]
# # Price

# %%
head5=soup.find_all('div',class_='font-semi-bold heading-6')
head5
# Out:
# [<div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">1,800 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>77,374/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->1.35 Crores</span></div>,
#  <div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">1,879 sqft</div></div>,
#  <div class="font-semi-bold heading-6" id="roomType"><span>₹</span>9,170/Month</div>,
#  <div class="font-semi-bold heading-6"><meta content="Minimum Deposit" itemprop="name"/><span>₹<!-- -->16 Lacs</span></div>,
# ...

# %%
pri=[]
for i in head5:
    i=i.get_text().replace("\n","")
    i=i.strip(" ")
    pri.append(i)
pri
# Out:
# ['1,800 sqft',
#  '₹77,374/Month',
#  '₹1.35 Crores',
#  '1,879 sqft',
#  '₹9,170/Month',
#  '₹16 Lacs',
#  '2,600 sqft',
#  '₹85,971/Month',
#  '₹1.5 Crores',
#  '2,000 sqft',
#  '₹39,546/Month',
#  '₹69 Lacs',
#  '3,000 sqft',
#  '₹71,643/Month',
#  '₹1.25 Crores',
#  '3,000 sqft',
#  '₹1.43 Lacs/Month',
#  '₹2.5 Crores',
#  '1,200 sqft',
#  '₹42,985/Month',
#  '₹75 Lacs',
#  '2,650 sqft',
#  '₹68,777/Month',
#  '₹1.2 Crores',
#  '3,100 sqft',
#  '₹85,971/Month',
#  '₹1.5 Crores',
#  '1,400 sqft',
#  '₹20,060/Month',
#  '₹35 Lacs']

# %%
price=[]
price=pri[2::3]
price
# Out:
# ['₹1.35 Crores',
#  '₹16 Lacs',
#  '₹1.5 Crores',
#  '₹69 Lacs',
#  '₹1.25 Crores',
#  '₹2.5 Crores',
#  '₹75 Lacs',
#  '₹1.2 Crores',
#  '₹1.5 Crores',
#  '₹35 Lacs']

# %% [markdown]
# # Database

# %%
dataset=pd.DataFrame()
dataset['House Names']=home
dataset['Area']=area
dataset['EMI']=emi
dataset['Cost']=price
dataset['Location']=des
dataset.head(10)
# Out:
#                                          House Names        Area  \
# 0  4 BHK In Independent House  For Sale  In Hebba...  1,800 sqft
# 1  4 BHK In Independent House  For Sale  In Hebba...  1,879 sqft
# 2  Independent House, Bangalore - Hosur Road, Nea...  2,600 sqft
# 3  4 BHK Flat  For Sale  In Sobha Silicon Oasis  ...  2,000 sqft
# 4  4 BHK Flat  For Sale  In Sobha Silicon Oasis  ...  3,000 sqft
# 5  Sobha Silicon Oasis Naganathapura, Rayasandra ...  3,000 sqft
# 6  4 BHK For Sale  In Daadys Garden In Electronic...  1,200 sqft
# 7  4 BHK For Sale  In Daadys Garden In Electronic...  2,650 sqft
# 8  Kammasandra Rd, Kammasandra, Electronic City, ...  3,100 sqft
# 9         4 BHK Flat  For Sale  In , Electronic City  1,400 sqft
#
#                 EMI          Cost  \
# 0     ₹77,374/Month  ₹1.35 Crores
# 1      ₹9,170/Month      ₹16 Lacs
# 2     ₹85,971/Month   ₹1.5 Crores
# 3     ₹39,546/Month      ₹69 Lacs
# 4     ₹71,643/Month  ₹1.25 Crores
# 5  ₹1.43 Lacs/Month   ₹2.5 Crores
# ...
